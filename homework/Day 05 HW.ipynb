# %% [markdown]
# ### 作業1 : 練習使用一個民生物聯網 API，例如空氣、地震等感測站所回傳的紀錄資料。¶
# 參考資料網址： https://ci.taiwan.gov.tw/dsp/environmental.aspx

# %%
import requests

URL = "https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/"
response = requests.get(URL)
result = response.json()

print(result)
# Out:
# {'value': [{'name': 'Datastreams', 'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/Datastreams'}, {'name': 'MultiDatastreams', 'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/MultiDatastreams'}, {'name': 'FeaturesOfInterest', 'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/FeaturesOfInterest'}, {'name': 'HistoricalLocations', 'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/HistoricalLocations'}, {'name': 'Locations', 'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/Locations'}, {'name': 'Observations', 'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/Observations'}, {'name': 'ObservedProperties', 'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/ObservedProperties'}, {'name': 'Sensors', 'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/Sensors'}, {'name': 'Things', 'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/Things'}]}

# %%
#不同方式列印_1

import json
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

jprint(result)
# Out:
# {
#     "value": [
#         {
#             "name": "Datastreams",
#             "url": "https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/Datastreams"
#         },
#         {
#             "name": "MultiDatastreams",
#             "url": "https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/MultiDatastreams"
#         },
#         {
#             "name": "FeaturesOfInterest",
#             "url": "https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/FeaturesOfInterest"
#         },
#         {
#             "name": "HistoricalLocations",
#             "url": "https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/HistoricalLocations"
#         },
#         {
#             "name": "Locations",
#             "url": "https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/Locations"
#         },
#         {
#             "name": "Observations",
#             "url": "https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/Observations"
#         },
#         {
# ...

# %%
#不同方式列印_2

import pprint
result = response.json()
pprint.pprint(result)
# Out:
# {'value': [{'name': 'Datastreams',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/Datastreams'},
#            {'name': 'MultiDatastreams',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/MultiDatastreams'},
#            {'name': 'FeaturesOfInterest',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/FeaturesOfInterest'},
#            {'name': 'HistoricalLocations',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/HistoricalLocations'},
#            {'name': 'Locations',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/Locations'},
#            {'name': 'Observations',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/Observations'},
#            {'name': 'ObservedProperties',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_Earthquake_v2/v1.0/ObservedProperties'},
#            {'name': 'Sensors',
# ...

# %% [markdown]
# ### 作業2 : 練習操作 OGC SensorThings API，將環保局測站位置的資料抓取下來，並且觀察下載資料的內容。
# 參考網址：https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things

# %%
URL2 = "https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things"
response2 = requests.get(URL2)
data = response2.json()
pprint.pprint(data)
# Out:
# {'@iot.count': 9703,
#  '@iot.nextLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things?$skip=100',
#  'value': [{'@iot.id': 1,
#             '@iot.selfLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)',
#             'Datastreams@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)/Datastreams',
#             'HistoricalLocations@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)/HistoricalLocations',
#             'Locations@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)/Locations',
#             'MultiDatastreams@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)/MultiDatastreams',
#             'TaskingCapabilities@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)/TaskingCapabilities',
#             'description': '智慧城鄉空品微型感測器-11113765144',
# ...

# %%
value = response2.json()['value']
for i in range(10):
    print("Description:", value[i]["description"])
# Out:
# Description: 智慧城鄉空品微型感測器-11113765144
# Description: 智慧城鄉空品微型感測器-11183695772
# Description: 智慧城鄉空品微型感測器-9330689794
# Description: 智慧城鄉空品微型感測器-7518931416
# Description: 智慧城鄉空品微型感測器-10054926614
# Description: 智慧城鄉空品微型感測器-8934297298
# Description: 智慧城鄉空品微型感測器-8983494557
# Description: 智慧城鄉空品微型感測器-9045855956
# Description: 智慧城鄉空品微型感測器-11181974894
# Description: 智慧城鄉空品微型感測器-9045719838

# %% [markdown]
# ### 作業3 : 依據作業 2 所下載的各個環保局測站感測器的描述資料，進一步點選 Datastreams、Locations，以及 Datastreams 點選進入後，點選 Observations 的 URL，觀察所下載到的資料內容，其中 Observations 內部是否包含個別感測器紀錄的資料

# %%
URL3="https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Things(1)/Datastreams"
response3 = requests.get(URL3)
result3 = response3.json()

jprint(result3)
# Out:
# {
#     "@iot.count": 3,
#     "value": [
#         {
#             "@iot.id": 2,
#             "@iot.selfLink": "https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Datastreams(2)",
#             "Observations@iot.navigationLink": "https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Datastreams(2)/Observations",
#             "ObservedProperty@iot.navigationLink": "https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Datastreams(2)/ObservedProperty",
#             "Sensor@iot.navigationLink": "https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Datastreams(2)/Sensor",
#             "Thing@iot.navigationLink": "https://sta.ci.taiwan.gov.tw/STA_AirQuality_EPAIoT/v1.0/Datastreams(2)/Thing",
#             "description": "\u76f8\u5c0d\u6ebc\u5ea6",
#             "name": "Relative humidity",
#             "observationType": "http://www.opengis.net/def/observationType/OGC-OM/2.0/OM_Measurement",
#             "observedArea": {
#                 "coordinates": [
# ...
